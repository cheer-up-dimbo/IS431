# %% [markdown]
# ### Label timestamp on video for easier labelling

# %%
# !ffmpeg \
  -i /home/yogee/Desktop/boxing_ai_ws/data_raw/sparring_pov/virtual_sparring.mp4 \
  -vf "drawtext=fontfile=/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf:\
text='%{pts\:hms}':x=10:y=10:fontsize=24:fontcolor=white:box=1:boxcolor=0x00000099"\
  -c:v libx264 -crf 18 -c:a copy \
  /home/yogee/Desktop/boxing_ai_ws/data_raw/sparring_pov/virtual_sparring_with_pts.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm10 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04.2)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm10 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm10 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yogee/Desktop/boxing_ai_ws/data_raw/sparring_pov/virtual_sparring.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2020-12-02T15:22:22.000000Z
#   Duration: 00:15:02.07, start: 0.000000, bitrate: 409 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 277 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2020-12-02T15:22:22.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/02/2020.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2020-12-02T15:22:22.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/02/2020.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5dc9612e1340] using SAR=1/1
# [libx264 @ 0x5dc9612e1340] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5dc9612e1340] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x5dc9612e1340] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yogee/Desktop/boxing_ai_ws/data_raw/sparring_pov/virtual_sparring_with_pts.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 11988 tbn (default)
#     Metadata:
#       creation_time   : 2020-12-02T15:22:22.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/02/2020.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2020-12-02T15:22:22.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/02/2020.
#       vendor_id       : [0][0][0][0]
# frame=27035 fps=454 q=-1.0 Lsize=   96159kB time=00:15:02.04 bitrate= 873.3kbits/s speed=15.1x
# video:81130kB audio:14095kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.980993%
# [libx264 @ 0x5dc9612e1340] frame I:109   Avg QP:13.19  size: 21769
# [libx264 @ 0x5dc9612e1340] frame P:9072  Avg QP:17.50  size:  5429
# [libx264 @ 0x5dc9612e1340] frame B:17854 Avg QP:23.61  size:  1762
# [libx264 @ 0x5dc9612e1340] consecutive B-frames:  3.3% 14.9% 33.0% 48.7%
# [libx264 @ 0x5dc9612e1340] mb I  I16..4: 16.3% 41.9% 41.7%
# [libx264 @ 0x5dc9612e1340] mb P  I16..4:  3.6%  9.7%  5.3%  P16..4: 22.5% 10.2%  4.5%  0.0%  0.0%    skip:44.2%
# [libx264 @ 0x5dc9612e1340] mb B  I16..4:  0.4%  1.6%  1.0%  B16..8: 22.5%  6.4%  1.4%  direct: 1.0%  skip:65.9%  L0:44.3% L1:46.8% BI: 8.9%
# [libx264 @ 0x5dc9612e1340] 8x8 transform intra:51.8% inter:59.1%
# [libx264 @ 0x5dc9612e1340] coded y,uvDC,uvAC intra: 66.3% 61.7% 34.5% inter: 8.2% 6.8% 1.3%
# [libx264 @ 0x5dc9612e1340] i16 v,h,dc,p: 27% 14%  7% 52%
# [libx264 @ 0x5dc9612e1340] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 19% 15%  4%  6%  7%  6%  6%  6%
# [libx264 @ 0x5dc9612e1340] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 18% 15%  5%  7%  8%  6%  6%  4%
# [libx264 @ 0x5dc9612e1340] i8c dc,h,v,p: 46% 20% 24% 10%
# [libx264 @ 0x5dc9612e1340] Weighted P-Frames: Y:2.2% UV:0.9%
# [libx264 @ 0x5dc9612e1340] ref P L0: 64.3% 13.5% 15.3%  6.8%  0.1%
# [libx264 @ 0x5dc9612e1340] ref B L0: 84.9% 12.6%  2.5%
# [libx264 @ 0x5dc9612e1340] ref B L1: 98.4%  1.6%
# [libx264 @ 0x5dc9612e1340] kb/s:736.76

# %% [markdown]
# ### Split Video using timestamps

# %%
import os
import subprocess
import pandas as pd
from pathlib import Path
from shutil import which

def find_video(video_name, search_dir="."):
    """
    Recursively search for "video_name.mp4" (case‐insensitive) under search_dir.
    Returns the first full path found, or None if not found.
    """
    target = f"{video_name.lower()}.mp4"
    for root, _, files in os.walk(search_dir):
        for f in files:
            if f.lower() == target:
                return os.path.join(root, f)
    return None

def ensure_ffmpeg_exists():
    """Raise an error if ffmpeg/ffprobe are not on PATH."""
    if which("ffmpeg") is None:
        raise RuntimeError("ffmpeg not found. Please install ffmpeg.")
    if which("ffprobe") is None:
        raise RuntimeError("ffprobe not found. Please install ffmpeg (includes ffprobe).")

def timestamp_to_seconds(ts_str):
    """Convert HH:MM:SS to total seconds."""
    h, m, s = map(int, ts_str.split(":"))
    return h*3600 + m*60 + s

def validate_timestamp(ts_str):
    """
    Normalize timestamp:
      - "MM:SS"        -> "00:MM:SS"
      - "HH:MM:00"     -> "00:HH:MM"
      - "HH:MM:SS"     -> unchanged
    """
    ts_str = ts_str.strip()
    parts = ts_str.split(":")
    # MM:SS (2 parts)
    if len(parts) == 2:
        mm, ss = map(int, parts)
        if 0 <= mm < 60 and 0 <= ss < 60:
            return f"00:{mm:02d}:{ss:02d}"
    # HH:MM:SS (3 parts)
    if len(parts) == 3:
        hh, mm, ss = map(int, parts)
        # if ends in :00, assume it was really MM:SS stored as HH:MM:00
        if ss == 0:
            return f"00:{hh:02d}:{mm:02d}"
        # otherwise valid HH:MM:SS
        if hh >= 0 and 0 <= mm < 60 and 0 <= ss < 60:
            return f"{hh:02d}:{mm:02d}:{ss:02d}"
    raise ValueError(f"Invalid timestamp format: '{ts_str}'")

def ffmpeg_cut_segment(input_path, start_ts, end_ts, output_path):
    """
    Reliable cut: seek before input, fixed duration, always re-encode
    with a keyframe at start and proper header.
    """
    start_sec = timestamp_to_seconds(start_ts)
    end_sec   = timestamp_to_seconds(end_ts)
    duration  = end_sec - start_sec
    if duration <= 0:
        raise RuntimeError(f"Invalid segment length: {start_ts} → {end_ts}")

    cmd = [
        "ffmpeg",
        "-hide_banner",
        "-loglevel", "info",
        "-ss",            start_ts,        # seek before input
        "-i",             input_path,
        "-t",             str(duration),   # duration in seconds
        "-c:v",           "libx264",       # re-encode video
        "-preset",        "fast",
        "-crf",           "23",
        "-c:a",           "aac",           # re-encode audio
        "-movflags",      "+faststart",    # header at front
        "-pix_fmt",       "yuv420p",
        "-y",
        output_path
    ]

    print(f"→ Cutting '{input_path}' from {start_ts} for {duration}s → '{output_path}'")
    result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print(result.stderr)
        raise RuntimeError(f"ffmpeg failed with code {result.returncode}")

    size = os.path.getsize(output_path)
    if size < 2000:
        raise RuntimeError(f"Output file too small ({size} bytes)")
    print(f"✔ Created: {output_path} ({size:,} bytes)")

def split_videos_from_sheet(sheet_path, search_dir, output_dir):
    ensure_ffmpeg_exists()

    # read spreadsheet, forcing Start/End as strings
    converters = {
        "Start": lambda x: str(x).strip(),
        "End":   lambda x: str(x).strip()
    }
    if sheet_path.lower().endswith(".csv"):
        df = pd.read_csv(sheet_path, converters=converters)
    else:
        df = pd.read_excel(sheet_path, converters=converters)
    df.columns = df.columns.str.strip()

    required = {"Video Name", "Start", "End", "Label"}
    if not required.issubset(df.columns):
        raise ValueError(f"Missing columns: found {df.columns.tolist()}")

    os.makedirs(output_dir, exist_ok=True)
    success = 0

    for idx, row in df.iterrows():
        try:
            name = str(row["Video Name"]).strip()
            if not name or name.lower() in ("nan", "none"):
                continue
            raw_start = row["Start"]
            raw_end   = row["End"]
            label     = str(row["Label"]).strip().lower().replace(" ", "_")

            print(f"\n[DEBUG] Row {idx+1}: Raw Start='{raw_start}', End='{raw_end}'")
            start_ts = validate_timestamp(raw_start)
            end_ts   = validate_timestamp(raw_end)
            print(f"[DEBUG] Row {idx+1}: Normalized {start_ts} → {end_ts}")

            video_path = find_video(name, search_dir)
            if video_path is None:
                print(f"[!] Video not found for '{name}' (skipping)")
                continue

            label_dir = os.path.join(output_dir, label)
            os.makedirs(label_dir, exist_ok=True)
            out_file = os.path.join(label_dir, f"{name}_{idx+1:03}.mp4")

            ffmpeg_cut_segment(video_path, start_ts, end_ts, out_file)
            success += 1

        except Exception as e:
            print(f"[X] Row {idx+1} failed: {e}")

    total = len(df)
    print(f"\nDone: {success}/{total} segments created.")

if __name__ == "__main__":
    split_videos_from_sheet(
        sheet_path="time_stamps/Boxing_Videos_Timestamp_repeated_punches.xlsx",
        search_dir=".",
        output_dir="dataset_repeated_punches"
    )
# Out:
# [DEBUG] Row 1: Raw Start='00:00', End='00:07'
# [DEBUG] Row 1: Normalized 00:00:00 → 00:00:07
# → Cutting './data_raw/repeated_punches/id0_hook_1.mp4' from 00:00:00 for 7s → 'dataset_repeated_punches/left_hook/id0_hook_1_001.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id0_hook_1_001.mp4 (5,580,782 bytes)
#
# [DEBUG] Row 2: Raw Start='00:09', End='00:17'
# [DEBUG] Row 2: Normalized 00:00:09 → 00:00:17
# → Cutting './data_raw/repeated_punches/id0_hook_1.mp4' from 00:00:09 for 8s → 'dataset_repeated_punches/right_hook/id0_hook_1_002.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id0_hook_1_002.mp4 (5,191,083 bytes)
#
# [DEBUG] Row 3: Raw Start='00:19', End='00:25'
# [DEBUG] Row 3: Normalized 00:00:19 → 00:00:25
# → Cutting './data_raw/repeated_punches/id0_hook_1.mp4' from 00:00:19 for 6s → 'dataset_repeated_punches/left_hook/id0_hook_1_003.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id0_hook_1_003.mp4 (4,506,121 bytes)
#
# [DEBUG] Row 4: Raw Start='00:28', End='00:35'
# [DEBUG] Row 4: Normalized 00:00:28 → 00:00:35
# → Cutting './data_raw/repeated_punches/id0_hook_1.mp4' from 00:00:28 for 7s → 'dataset_repeated_punches/right_hook/id0_hook_1_004.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id0_hook_1_004.mp4 (5,067,505 bytes)
#
# [DEBUG] Row 5: Raw Start='00:00', End='00:07'
# [DEBUG] Row 5: Normalized 00:00:00 → 00:00:07
# → Cutting './data_raw/repeated_punches/id0_hook_2.mp4' from 00:00:00 for 7s → 'dataset_repeated_punches/left_hook/id0_hook_2_005.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id0_hook_2_005.mp4 (5,884,529 bytes)
#
# [DEBUG] Row 6: Raw Start='00:09', End='00:16'
# [DEBUG] Row 6: Normalized 00:00:09 → 00:00:16
# → Cutting './data_raw/repeated_punches/id0_hook_2.mp4' from 00:00:09 for 7s → 'dataset_repeated_punches/right_hook/id0_hook_2_006.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id0_hook_2_006.mp4 (5,231,171 bytes)
#
# [DEBUG] Row 7: Raw Start='00:18', End='00:22'
# [DEBUG] Row 7: Normalized 00:00:18 → 00:00:22
# → Cutting './data_raw/repeated_punches/id0_hook_2.mp4' from 00:00:18 for 4s → 'dataset_repeated_punches/left_hook/id0_hook_2_007.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id0_hook_2_007.mp4 (3,226,045 bytes)
#
# [DEBUG] Row 8: Raw Start='00:26', End='00:32'
# [DEBUG] Row 8: Normalized 00:00:26 → 00:00:32
# → Cutting './data_raw/repeated_punches/id0_hook_2.mp4' from 00:00:26 for 6s → 'dataset_repeated_punches/right_hook/id0_hook_2_008.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id0_hook_2_008.mp4 (4,630,779 bytes)
#
# [DEBUG] Row 9: Raw Start='00:00', End='00:06'
# [DEBUG] Row 9: Normalized 00:00:00 → 00:00:06
# → Cutting './data_raw/repeated_punches/id0_jab_1.mp4' from 00:00:00 for 6s → 'dataset_repeated_punches/jab/id0_jab_1_009.mp4'
# ✔ Created: dataset_repeated_punches/jab/id0_jab_1_009.mp4 (4,196,085 bytes)
#
# [DEBUG] Row 10: Raw Start='00:07', End='00:14'
# [DEBUG] Row 10: Normalized 00:00:07 → 00:00:14
# → Cutting './data_raw/repeated_punches/id0_jab_1.mp4' from 00:00:07 for 7s → 'dataset_repeated_punches/cross/id0_jab_1_010.mp4'
# ✔ Created: dataset_repeated_punches/cross/id0_jab_1_010.mp4 (4,918,710 bytes)
#
# [DEBUG] Row 11: Raw Start='00:15', End='00:22'
# [DEBUG] Row 11: Normalized 00:00:15 → 00:00:22
# → Cutting './data_raw/repeated_punches/id0_jab_1.mp4' from 00:00:15 for 7s → 'dataset_repeated_punches/jab/id0_jab_1_011.mp4'
# ✔ Created: dataset_repeated_punches/jab/id0_jab_1_011.mp4 (5,122,717 bytes)
#
# [DEBUG] Row 12: Raw Start='00:23', End='00:30'
# [DEBUG] Row 12: Normalized 00:00:23 → 00:00:30
# → Cutting './data_raw/repeated_punches/id0_jab_1.mp4' from 00:00:23 for 7s → 'dataset_repeated_punches/cross/id0_jab_1_012.mp4'
# ✔ Created: dataset_repeated_punches/cross/id0_jab_1_012.mp4 (5,343,896 bytes)
#
# [DEBUG] Row 13: Raw Start='00:00', End='00:10'
# [DEBUG] Row 13: Normalized 00:00:00 → 00:00:10
# → Cutting './data_raw/repeated_punches/id0_uper_1.mp4' from 00:00:00 for 10s → 'dataset_repeated_punches/left_uppercut/id0_uper_1_013.mp4'
# ✔ Created: dataset_repeated_punches/left_uppercut/id0_uper_1_013.mp4 (7,368,395 bytes)
#
# [DEBUG] Row 14: Raw Start='00:12', End='00:19'
# [DEBUG] Row 14: Normalized 00:00:12 → 00:00:19
# → Cutting './data_raw/repeated_punches/id0_uper_1.mp4' from 00:00:12 for 7s → 'dataset_repeated_punches/right_uppercut/id0_uper_1_014.mp4'
# ✔ Created: dataset_repeated_punches/right_uppercut/id0_uper_1_014.mp4 (4,798,167 bytes)
#
# [DEBUG] Row 15: Raw Start='00:22', End='00:29'
# [DEBUG] Row 15: Normalized 00:00:22 → 00:00:29
# → Cutting './data_raw/repeated_punches/id0_uper_1.mp4' from 00:00:22 for 7s → 'dataset_repeated_punches/left_uppercut/id0_uper_1_015.mp4'
# ✔ Created: dataset_repeated_punches/left_uppercut/id0_uper_1_015.mp4 (5,324,901 bytes)
#
# [DEBUG] Row 16: Raw Start='00:32', End='00:38'
# [DEBUG] Row 16: Normalized 00:00:32 → 00:00:38
# → Cutting './data_raw/repeated_punches/id0_uper_1.mp4' from 00:00:32 for 6s → 'dataset_repeated_punches/right_uppercut/id0_uper_1_016.mp4'
# ✔ Created: dataset_repeated_punches/right_uppercut/id0_uper_1_016.mp4 (4,483,822 bytes)
#
# [DEBUG] Row 17: Raw Start='00:00', End='00:05'
# [DEBUG] Row 17: Normalized 00:00:00 → 00:00:05
# → Cutting './data_raw/repeated_punches/id1_hook_1.mp4' from 00:00:00 for 5s → 'dataset_repeated_punches/left_hook/id1_hook_1_017.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id1_hook_1_017.mp4 (3,054,336 bytes)
#
# [DEBUG] Row 18: Raw Start='00:07', End='00:11'
# [DEBUG] Row 18: Normalized 00:00:07 → 00:00:11
# → Cutting './data_raw/repeated_punches/id1_hook_1.mp4' from 00:00:07 for 4s → 'dataset_repeated_punches/right_hook/id1_hook_1_018.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id1_hook_1_018.mp4 (2,585,230 bytes)
#
# [DEBUG] Row 19: Raw Start='00:15', End='00:19'
# [DEBUG] Row 19: Normalized 00:00:15 → 00:00:19
# → Cutting './data_raw/repeated_punches/id1_hook_1.mp4' from 00:00:15 for 4s → 'dataset_repeated_punches/left_hook/id1_hook_1_019.mp4'
# ✔ Created: dataset_repeated_punches/left_hook/id1_hook_1_019.mp4 (2,657,920 bytes)
#
# [DEBUG] Row 20: Raw Start='00:21', End='00:27'
# [DEBUG] Row 20: Normalized 00:00:21 → 00:00:27
# → Cutting './data_raw/repeated_punches/id1_hook_1.mp4' from 00:00:21 for 6s → 'dataset_repeated_punches/right_hook/id1_hook_1_020.mp4'
# ✔ Created: dataset_repeated_punches/right_hook/id1_hook_1_020.mp4 (3,849,639 bytes)
#
# [DEBUG] Row 21: Raw Start='00:00', End='00:04'
# [DEBUG] Row 21: Normalized 00:00:00 → 00:00:04
# → Cutting './data_raw/repeated_punches/id1_uper_1.mp4' from 00:00:00 for 4s → 'dataset_repeated_punches/left_uppercut/id1_uper_1_021.mp4'
# ✔ Created: dataset_repeated_punches/left_uppercut/id1_uper_1_021.mp4 (2,288,568 bytes)
#
# [DEBUG] Row 22: Raw Start='00:06', End='00:11'
# [DEBUG] Row 22: Normalized 00:00:06 → 00:00:11
# → Cutting './data_raw/repeated_punches/id1_uper_1.mp4' from 00:00:06 for 5s → 'dataset_repeated_punches/right_uppercut/id1_uper_1_022.mp4'
# ✔ Created: dataset_repeated_punches/right_uppercut/id1_uper_1_022.mp4 (3,005,529 bytes)
#
# [DEBUG] Row 23: Raw Start='00:14', End='00:17'
# [DEBUG] Row 23: Normalized 00:00:14 → 00:00:17
# → Cutting './data_raw/repeated_punches/id1_uper_1.mp4' from 00:00:14 for 3s → 'dataset_repeated_punches/left_uppercut/id1_uper_1_023.mp4'
# ✔ Created: dataset_repeated_punches/left_uppercut/id1_uper_1_023.mp4 (1,923,402 bytes)
#
# [DEBUG] Row 24: Raw Start='00:19', End='00:23'
# [DEBUG] Row 24: Normalized 00:00:19 → 00:00:23
# → Cutting './data_raw/repeated_punches/id1_uper_1.mp4' from 00:00:19 for 4s → 'dataset_repeated_punches/right_uppercut/id1_uper_1_024.mp4'
# ✔ Created: dataset_repeated_punches/right_uppercut/id1_uper_1_024.mp4 (2,727,588 bytes)
#
# Done: 24/24 segments created.

# %% [markdown]
# ### Dataset with poses

# %%
# %pip install opencv-python
# %pip install ultralytics
# %pip install imageio[ffmpeg]
# Out:
# Requirement already satisfied: opencv-python in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from opencv-python) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ultralytics in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (8.3.225)
# Requirement already satisfied: numpy>=1.23.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: psutil in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (6.1.1)
# Requirement already satisfied: polars in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (1.35.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=3 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: setuptools in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (75.8.1)
# Requirement already satisfied: sympy==1.13.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: polars-runtime-32==1.35.1 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from polars->ultralytics) (1.35.1)
# Requirement already satisfied: six>=1.5 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imageio[ffmpeg] in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (2.37.2)
# Requirement already satisfied: numpy in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from imageio[ffmpeg]) (2.2.3)
# Requirement already satisfied: pillow>=8.3.2 in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from imageio[ffmpeg]) (11.1.0)
# Requirement already satisfied: imageio-ffmpeg in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from imageio[ffmpeg]) (0.6.0)
# Requirement already satisfied: psutil in /home/yogee/miniconda3/envs/ML/lib/python3.13/site-packages (from imageio[ffmpeg]) (6.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import imageio
import numpy as np
import pandas as pd
from ultralytics import YOLO

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ─────────────────────────────────────────────────────────────────────────────
POSE_MODEL_PATH = "models/yolo11m-pose.pt"      # path to your YOLO-pose .pt file
VIDEO_ROOTS     = ["dataset_sparring_pov", "dataset_repeated_punches"]  # list of folders to include
OUTPUT_ROOT     = "dataset_with_poses"          # root where .npy and labels.csv will be saved

# ─────────────────────────────────────────────────────────────────────────────
# Utility Functions
# ─────────────────────────────────────────────────────────────────────────────

def read_frames(path):
    """Read all RGB frames from a video via imageio or OpenCV."""
    try:
        reader = imageio.get_reader(path, "ffmpeg")
        frames = [f for f in reader]
        reader.close()
        if frames:
            return frames
    except Exception:
        pass
    cap = cv2.VideoCapture(path)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {path}")
    frames = []
    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            break
        frames.append(cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB))
    cap.release()
    if not frames:
        raise RuntimeError(f"No frames read from: {path}")
    return frames


def extract_pose_sequence(model, video_path):
    """
    Run pose model on each frame. Returns numpy array shape (num_frames, 2*num_keypoints).
    """
    frames = read_frames(video_path)
    if not frames:
        return None

    # Infer number of keypoints by running on first frame with a detection
    num_kpts = None
    for frame in frames:
        results = model(frame)
        if results and results[0].keypoints is not None:
            kps = results[0].keypoints.xy.cpu().numpy()
            if kps.size:
                num_kpts = kps.shape[1]
                break
    if num_kpts is None:
        raise RuntimeError("No keypoints found; cannot infer count.")

    seq = []
    for frame in frames:
        results = model(frame)
        if results and results[0].keypoints is not None:
            kps = results[0].keypoints.xy.cpu().numpy()
            if kps.size > 0:
                coords = kps[0, :, :2].flatten()
            else:
                coords = np.zeros(num_kpts * 2, dtype=float)
        else:
            coords = np.zeros(num_kpts * 2, dtype=float)
        seq.append(coords)

    return np.stack(seq, axis=0)


# ─────────────────────────────────────────────────────────────────────────────
# Main Extraction: Walk across multiple dataset roots
# ─────────────────────────────────────────────────────────────────────────────

model = YOLO(POSE_MODEL_PATH)
records = []
os.makedirs(OUTPUT_ROOT, exist_ok=True)

for root in VIDEO_ROOTS:
    if not os.path.isdir(root):
        print(f"Skipping missing folder: {root}")
        continue

    for dirpath, _, files in os.walk(root):
        for fname in files:
            if not fname.lower().endswith('.mp4'):
                continue
            video_path = os.path.join(dirpath, fname)

            # Derive label from the subfolder name relative to dataset root
            rel_path = os.path.relpath(dirpath, root)
            label = os.path.normpath(rel_path).replace(os.sep, '_') or "root"
            clip = os.path.splitext(fname)[0]
            print(f"Processing [{label}] {clip}.mp4")

            try:
                seq = extract_pose_sequence(model, video_path)
            except Exception as e:
                print(f"  ↳ error extracting poses: {e}")
                continue
            if seq is None or seq.size == 0:
                print("  ↳ no pose data: skipping")
                continue

            # Save in separate label folders (original behavior)
            out_dir = os.path.join(OUTPUT_ROOT, label)
            os.makedirs(out_dir, exist_ok=True)
            npy_path = os.path.join(out_dir, f"{clip}.npy")
            np.save(npy_path, seq)

            records.append({'npy_path': npy_path, 'label': label})
            print(f"  ↳ saved {npy_path} (shape={seq.shape})")

# Write labels.csv at root
if records:
    df = pd.DataFrame(records)
    csv_file = os.path.join(OUTPUT_ROOT, 'labels.csv')
    df.to_csv(csv_file, index=False)
    print(f"labels.csv written to {csv_file}")
else:
    print("No pose data extracted; check your folders and model.")
# Out:
# Processing [block] slow_motion_sparring_009.mp4
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person,
7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.9ms
# Speed: 4.1ms preprocess, 45.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.1ms
# Speed: 5.5ms preprocess, 46.1ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.7ms
# Speed: 6.3ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.5ms
# Speed: 5.3ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.1ms
# Speed: 5.4ms preprocess, 44.1ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.5ms
# Speed: 5.2ms preprocess, 46.5ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.9ms
# Speed: 5.1ms preprocess, 43.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.7ms
# Speed: 5.0ms preprocess, 40.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.8ms
# Speed: 5.1ms preprocess, 41.8ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.0ms
# Speed: 5.3ms preprocess, 42.0ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.0ms
# Speed: 10.4ms preprocess, 48.0ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 51.3ms
# Speed: 5.5ms preprocess, 51.3ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 37.0ms
# Speed: 6.2ms preprocess, 37.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.5ms
# Speed: 6.5ms preprocess, 44.5ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 5.5ms preprocess, 47.4ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 60.0ms
# Speed: 5.4ms preprocess, 60.0ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 37.2ms
# Speed: 3.3ms preprocess, 37.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.9ms
# Speed: 2.7ms preprocess, 47.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 2.6ms preprocess, 45.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.3ms
# Speed: 6.0ms preprocess, 43.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.7ms
# Speed: 2.5ms preprocess, 45.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.1ms
# Speed: 4.0ms preprocess, 40.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#   ↳ saved dataset_with_poses/cross/id0_jab_1_010.npy (shape=(210, 34))
# labels.csv written to dataset_with_poses/labels.csv

# %% [markdown]
# ### Visualize pose estimation on Videos in 1 folder

# %%
# Batch Overlay from Numpy Pose Data (Notebook-Friendly)

import os
import cv2
import numpy as np
from IPython.display import Video, display

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ─────────────────────────────────────────────────────────────────────────────
VIDEO_ROOT   = "dataset"                        # root folder with label subfolders of .mp4
NPY_ROOT     = "dataset_with_poses"            # root folder with label subfolders of .npy
OUTPUT_ROOT  = "dataset_with_poses_visualization"  # where to save annotated videos
POINT_RADIUS = 4
LINE_THICK   = 2

# COCO skeleton connections (0-indexed keypoints)
SKELETON = [
    (0, 1), (0, 2), (1, 3), (2, 4),  # head
    (0, 5), (0, 6),                    # shoulders
    (5, 7), (7, 9),                    # left arm
    (6, 8), (8, 10),                   # right arm
    (5, 6),                            # across shoulders
    (5, 11), (6, 12),                  # torso sides
    (11, 12),                          # across hips
    (11, 13), (13, 15),                # left leg
    (12, 14), (14, 16)                 # right leg
]

# ─────────────────────────────────────────────────────────────────────────────
# Helper: Annotate one video given its pose array
# ─────────────────────────────────────────────────────────────────────────────
def annotate_video(video_path, poses, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {video_path}")
    fps = cap.get(cv2.CAP_PROP_FPS) or 30
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(output_path, fourcc, fps, (w, h))
    num_frames = poses.shape[0]
    num_kpts = poses.shape[1] // 2

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_idx < num_frames:
            coords = poses[frame_idx].reshape(num_kpts, 2)
            # draw skeleton
            for i, j in SKELETON:
                x1, y1 = coords[i]
                x2, y2 = coords[j]
                if x1>0 and y1>0 and x2>0 and y2>0 and x1<w and y1<h and x2<w and y2<h:
                    cv2.line(frame, (int(x1),int(y1)), (int(x2),int(y2)), (0,255,0), LINE_THICK)
            # draw points
            for x, y in coords:
                if x>0 and y>0 and x<w and y<h:
                    cv2.circle(frame, (int(x),int(y)), POINT_RADIUS, (0,0,255), -1)
        writer.write(frame)
        frame_idx += 1
    cap.release()
    writer.release()
    return output_path

# ─────────────────────────────────────────────────────────────────────────────
# Batch Processing: Iterate over labels and videos
# ─────────────────────────────────────────────────────────────────────────────
os.makedirs(OUTPUT_ROOT, exist_ok=True)

for label in os.listdir(VIDEO_ROOT):
    vdir = os.path.join(VIDEO_ROOT, label)
    ndir = os.path.join(NPY_ROOT, label)
    odir = os.path.join(OUTPUT_ROOT, label)
    if not os.path.isdir(vdir) or not os.path.isdir(ndir):
        continue
    os.makedirs(odir, exist_ok=True)
    for fname in os.listdir(vdir):
        if not fname.lower().endswith('.mp4'):
            continue
        clip = os.path.splitext(fname)[0]
        video_path = os.path.join(vdir, fname)
        npy_path = os.path.join(ndir, f"{clip}.npy")
        if not os.path.exists(npy_path):
            print(f"No pose data for {clip}, skipping")
            continue
        poses = np.load(npy_path)
        out_video = os.path.join(odir, f"{clip}_annotated.mp4")
        print(f"Annotating {label}/{clip}.mp4 → {out_video}")
        annotate_video(video_path, poses, out_video)

# ─────────────────────────────────────────────────────────────────────────────
# Display one sample annotated video
# ─────────────────────────────────────────────────────────────────────────────
# Find first annotated file
for root, _, files in os.walk(OUTPUT_ROOT):
    for f in files:
        if f.lower().endswith('_annotated.mp4'):
            display(Video(os.path.join(root, f), embed=True, width=600))
            raise SystemExit

print("Batch annotation complete. Check", OUTPUT_ROOT)
# Out:
# Batch annotation complete. Check dataset_with_poses_visualization

# %% [markdown]
# ### Visualize pose estimation for 1 video only

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Batch or Single Video Pose Visualization (Notebook-Friendly + Stable)
# ─────────────────────────────────────────────────────────────────────────────
import os
import cv2
import numpy as np
from IPython.display import Video, display

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ─────────────────────────────────────────────────────────────────────────────
VIDEO_ROOT   = "dataset"                        # root folder with label subfolders of .mp4
NPY_ROOT     = "dataset_with_poses"             # root folder with label subfolders of .npy
OUTPUT_ROOT  = "dataset_with_poses_visualization"  # where to save annotated videos
POINT_RADIUS = 4
LINE_THICK   = 2

# ▶️ Specify one exact video (optional)
# Leave both empty to run batch mode
SPECIFIC_VIDEO = "dataset_sparring_pov/right_hook/slow_motion_sparring_069.mp4"
SPECIFIC_NPY   = "dataset_with_poses/right_hook/slow_motion_sparring_069.npy"

# COCO skeleton connections (0-indexed keypoints)
SKELETON = [
    (0, 1), (0, 2), (1, 3), (2, 4),  # head
    (0, 5), (0, 6),                  # shoulders
    (5, 7), (7, 9),                  # left arm
    (6, 8), (8, 10),                 # right arm
    (5, 6),                          # across shoulders
    (5, 11), (6, 12),                # torso sides
    (11, 12),                        # across hips
    (11, 13), (13, 15),              # left leg
    (12, 14), (14, 16)               # right leg
]

# ─────────────────────────────────────────────────────────────────────────────
# Helper: Annotate one video given its pose array
# ─────────────────────────────────────────────────────────────────────────────
def annotate_video(video_path, poses, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {video_path}")
    fps = cap.get(cv2.CAP_PROP_FPS) or 30
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # ✅ stable codec
    writer = cv2.VideoWriter(output_path, fourcc, fps, (w, h))
    num_frames = poses.shape[0]
    num_kpts = poses.shape[1] // 2

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_idx < num_frames:
            coords = poses[frame_idx].reshape(num_kpts, 2)
            # draw skeleton
            for i, j in SKELETON:
                x1, y1 = coords[i]
                x2, y2 = coords[j]
                if x1>0 and y1>0 and x2>0 and y2>0 and x1<w and y1<h and x2<w and y2<h:
                    cv2.line(frame, (int(x1),int(y1)), (int(x2),int(y2)), (0,255,0), LINE_THICK)
            # draw points
            for x, y in coords:
                if x>0 and y>0 and x<w and y<h:
                    cv2.circle(frame, (int(x),int(y)), POINT_RADIUS, (0,0,255), -1)
        writer.write(frame)
        frame_idx += 1
    cap.release()
    writer.release()
    return output_path

# ─────────────────────────────────────────────────────────────────────────────
# SINGLE VIDEO MODE
# ─────────────────────────────────────────────────────────────────────────────
if SPECIFIC_VIDEO and SPECIFIC_NPY:
    if not os.path.exists(SPECIFIC_VIDEO):
        raise FileNotFoundError(f"Missing video: {SPECIFIC_VIDEO}")
    if not os.path.exists(SPECIFIC_NPY):
        raise FileNotFoundError(f"Missing pose file: {SPECIFIC_NPY}")

    base = os.path.splitext(os.path.basename(SPECIFIC_VIDEO))[0]
    label = os.path.basename(os.path.dirname(SPECIFIC_VIDEO))
    out_dir = os.path.join(OUTPUT_ROOT, label)
    os.makedirs(out_dir, exist_ok=True)
    output_path = os.path.join(out_dir, f"{base}_annotated.mp4")

    poses = np.load(SPECIFIC_NPY)
    print(f"Annotating single video: {SPECIFIC_VIDEO} ({poses.shape[0]} frames)")
    annotate_video(SPECIFIC_VIDEO, poses, output_path)
    print(f"✅ Saved annotated video to: {output_path}")
    display(Video(output_path, embed=True, width=600))

else:
    # ─────────────────────────────────────────────────────────────────────────
    # BATCH MODE: Iterate through dataset (unchanged from your working version)
    # ─────────────────────────────────────────────────────────────────────────
    os.makedirs(OUTPUT_ROOT, exist_ok=True)

    for label in os.listdir(VIDEO_ROOT):
        vdir = os.path.join(VIDEO_ROOT, label)
        ndir = os.path.join(NPY_ROOT, label)
        odir = os.path.join(OUTPUT_ROOT, label)
        if not os.path.isdir(vdir) or not os.path.isdir(ndir):
            continue
        os.makedirs(odir, exist_ok=True)
        for fname in os.listdir(vdir):
            if not fname.lower().endswith('.mp4'):
                continue
            clip = os.path.splitext(fname)[0]
            video_path = os.path.join(vdir, fname)
            npy_path = os.path.join(ndir, f"{clip}.npy")
            if not os.path.exists(npy_path):
                print(f"No pose data for {clip}, skipping")
                continue
            poses = np.load(npy_path)
            out_video = os.path.join(odir, f"{clip}_annotated.mp4")
            print(f"Annotating {label}/{clip}.mp4 → {out_video}")
            annotate_video(video_path, poses, out_video)

    # Display first annotated video found
    for root, _, files in os.walk(OUTPUT_ROOT):
        for f in files:
            if f.lower().endswith('_annotated.mp4'):
                display(Video(os.path.join(root, f), embed=True, width=600))
                raise SystemExit

    print("Batch annotation complete. Check", OUTPUT_ROOT)
# Out:
# Annotating single video: dataset_sparring_pov/right_hook/slow_motion_sparring_069.mp4 (60 frames)
# ✅ Saved annotated video to: dataset_with_poses_visualization/right_hook/slow_motion_sparring_069_annotated.mp4
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Convert video to H264 using ffmpeg

# %%
# !ffmpeg -y -i "/home/yogee/Desktop/boxing_ai_ws/zakir_bottom_pred.mp4" \
        -vcodec libx264 -acodec aac \
        "/home/yogee/Desktop/boxing_ai_ws/zakir_bottom_pred_h264.mp4"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm10 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04.2)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm10 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm10 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yogee/Desktop/boxing_ai_ws/zakir_bottom_pred.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:05.70, start: 0.000000, bitrate: 10241 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 10240 kb/s, 30.01 fps, 30.01 tbr, 30009 tbn, 30009 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x630f2c2d4dc0] using SAR=1/1
# [libx264 @ 0x630f2c2d4dc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x630f2c2d4dc0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x630f2c2d4dc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yogee/Desktop/boxing_ai_ws/zakir_bottom_pred_h264.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 30.01 fps, 30009 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  171 fps= 62 q=-1.0 Lsize=    2351kB time=00:00:05.59 bitrate=3440.5kbits/s speed=2.04x
# video:2349kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.112395%
# [libx264 @ 0x630f2c2d4dc0] frame I:1     Avg QP:22.02  size: 47225
# [libx264 @ 0x630f2c2d4dc0] frame P:77    Avg QP:23.54  size: 19542
# [libx264 @ 0x630f2c2d4dc0] frame B:93    Avg QP:26.22  size:  9164
# [libx264 @ 0x630f2c2d4dc0] consecutive B-frames: 21.6% 12.9% 14.0% 51.5%
# [libx264 @ 0x630f2c2d4dc0] mb I  I16..4: 27.2% 69.6%  3.1%
# [libx264 @ 0x630f2c2d4dc0] mb P  I16..4:  4.1% 15.6%  1.6%  P16..4: 42.9% 10.5%  5.5%  0.0%  0.0%    skip:19.8%
# [libx264 @ 0x630f2c2d4dc0] mb B  I16..4:  1.1%  4.7%  0.5%  B16..8: 39.2%  5.7%  1.5%  direct: 1.2%  skip:46.1%  L0:53.9% L1:40.5% BI: 5.6%
# [libx264 @ 0x630f2c2d4dc0] 8x8 transform intra:73.3% inter:80.4%
# [libx264 @ 0x630f2c2d4dc0] coded y,uvDC,uvAC intra: 50.4% 70.3% 14.3% inter: 13.1% 18.0% 3.3%
# [libx264 @ 0x630f2c2d4dc0] i16 v,h,dc,p: 30% 30% 24% 16%
# [libx264 @ 0x630f2c2d4dc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 22% 32%  5%  3%  3%  3%  5%  4%
# [libx264 @ 0x630f2c2d4dc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 17% 17%  7%  6%  7%  5%  7%  4%
# [libx264 @ 0x630f2c2d4dc0] i8c dc,h,v,p: 45% 24% 27%  5%
# [libx264 @ 0x630f2c2d4dc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x630f2c2d4dc0] ref P L0: 68.5% 12.8% 14.2%  4.5%
# [libx264 @ 0x630f2c2d4dc0] ref B L0: 89.2%  9.0%  1.8%
# [libx264 @ 0x630f2c2d4dc0] ref B L1: 97.5%  2.5%
# [libx264 @ 0x630f2c2d4dc0] kb/s:3375.37
